# %%
# %pip install matplotlib seaborn
# Out:
# Active code page: 1252
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
namelist = np.array(['Angel', "Shemi"])
print(namelist)
print(namelist.shape)
# Out:
# ['Angel' 'Shemi']
# (2,)
