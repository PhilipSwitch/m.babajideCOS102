# %%
# Fintech company project
experience = int(input("Input your years of experience"))
age = int(input("Input your age"))

if experience > 25 and age >= 55:
    print("Your ATR is N5,600,000")
elif experience > 20 and age >= 45:
    print("Your ATR is N4,480,000")
elif experience >= 10 and age >= 35:
    print("your ATR is N1,500,000")
else: print("Your ATR is N550,000")
# Out:
# Input your years of experience 21
# Input your age 55
# Your ATR is N4,480,000
